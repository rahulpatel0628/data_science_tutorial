# %% [markdown]
# # Redge Regression Using Gradient Descent

# %%
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# %%
data=load_diabetes()
x=data.data
y=data.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
class MyGradientDescentForRidgeRegression:
    def __init__(self,alpha,lr,epochs):
        self.lr=lr
        self.alpha=alpha
        self.epochs=epochs
        self.coef_=None
        self.intercept_=None
    def fit(self,x_train,y_train):
        self.intercept_=0
        self.coef_=np.ones(x_train.shape[1])
        theta=np.insert(self.coef_,0,self.intercept_)
        x_train=np.insert(x_train,0,1,axis=1)
        for i in range(self.epochs):
            theta_der=np.dot(x_train.T,x_train).dot(theta) - np.dot(x_train.T,y_train) + self.alpha*theta
            theta=theta - self.lr*theta_der
        self.intercept_=theta[0]
        self.coef_=theta[1:]
    def predict(self,x_test):
        return self.intercept_ + np.dot(x_test,self.coef_)

# %%
mrr=MyGradientDescentForRidgeRegression(alpha=0.001,lr=0.005,epochs=5000)

# %%
mrr.fit(x_train,y_train)

# %%
y_pred=mrr.predict(x_test)

# %%
mrr.coef_
# Out:
# array([  41.89172348, -239.95568825,  555.78399797,  342.87078753,
#        -207.35778703,  -47.93586632, -163.14945892,  172.1336934 ,
#         459.28202598,   54.18771931])

# %%
mrr.intercept_
# Out:
# 151.30982897261634

# %%
r2_score(y_test,y_pred)
# Out:
# 0.455421968920926
