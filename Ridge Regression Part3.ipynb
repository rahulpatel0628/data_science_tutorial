# %%
import numpy as np
from sklearn.datasets import load_diabetes
from sklearn.model_selection import train_test_split
from sklearn.linear_model import Ridge
from sklearn.metrics import r2_score

# %%
data=load_diabetes()
x=data.data
y=data.target

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
rr=Ridge(alpha=0.0001)
rr.fit(x_train,y_train)
r2_score(y_test,rr.predict(x_test))
# Out:
# 0.4526998154220113

# %% [markdown]
# # My Own Mupliple Ridge Regression

# %%
class MyOwn:
    def __init__(self,alpha):
        self.alpha=alpha
        self.coef_=None
        self.intercept_=None
    def fit(self,x_train,y_train):
        x_train=np.insert(x_train,0,1,axis=1)
        I=np.identity(x_train.shape[1])
        
        result=np.linalg.inv(np.dot(x_train.T,x_train)+self.alpha*I).dot(x_train.T).dot(y_train)
        self.intercept_=result[0]
        self.coef_=result[1:]
    def predict(self,x_test):
        return self.intercept_ +np.dot(x_test,self.coef_)

# %%
MWRR=MyOwn(0.1)

# %%
MWRR.fit(x_train,y_train)
print(r2_score(y_test,MWRR.predict(x_test)))
print(MWRR.coef_)
print(MWRR.intercept_)
# Out:
# 0.46079113966831786
# [  42.87709893 -205.49834268  505.10960427  317.09526097 -108.51126124
#   -86.2562279  -190.37246178  151.70037599  392.29679967   79.93194581]
# 151.41552984312938
